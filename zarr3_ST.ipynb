# %%
import os
import numpy as np
import xarray as xr
import rioxarray
import zarr
from numcodecs import Blosc
import datetime
import glob
import re
import gc
import rasterio.errors

# %%
zarr_path = "../../../eodc/products/eodc/clms_vegetation_total_productivity/CLMS.zarr"

start_year = 2017
end_year = 2025
# now = datetime.datetime.now()
# end_year = now.year

# Days of the month you want
days = [1, 11, 21]

# Generate all dates
dates = []
for year in range(start_year, end_year + 1):
    for month in range(1, 13):
        for day in days:
            try:
                dates.append(np.datetime64(datetime.date(year, month, day)))
            except ValueError:
                # In case of invalid dates like Feb 30
                pass

dates = np.array(dates)
dates = dates.astype("datetime64[D]") 
time_int = dates.astype("int64")

# %%
# Convert datetime64[D] to int YYYYMMDD
dates_int = (dates.astype('datetime64[D]')
                 .astype('O'))  # convert to Python datetime.date
dates_int = np.array([d.year * 10000 + d.month * 100 + d.day for d in dates_int], dtype='int32')
dates_int
# Out:
# array([20170101, 20170111, 20170121, 20170201, 20170211, 20170221,
#        20170301, 20170311, 20170321, 20170401, 20170411, 20170421,
#        20170501, 20170511, 20170521, 20170601, 20170611, 20170621,
#        20170701, 20170711, 20170721, 20170801, 20170811, 20170821,
#        20170901, 20170911, 20170921, 20171001, 20171011, 20171021,
#        20171101, 20171111, 20171121, 20171201, 20171211, 20171221,
#        20180101, 20180111, 20180121, 20180201, 20180211, 20180221,
#        20180301, 20180311, 20180321, 20180401, 20180411, 20180421,
#        20180501, 20180511, 20180521, 20180601, 20180611, 20180621,
#        20180701, 20180711, 20180721, 20180801, 20180811, 20180821,
#        20180901, 20180911, 20180921, 20181001, 20181011, 20181021,
#        20181101, 20181111, 20181121, 20181201, 20181211, 20181221,
#        20190101, 20190111, 20190121, 20190201, 20190211, 20190221,
#        20190301, 20190311, 20190321, 20190401, 20190411, 20190421,
#        20190501, 20190511, 20190521, 20190601, 20190611, 20190621,
#        20190701, 20190711, 20190721, 20190801, 20190811, 20190821,
#        20190901, 20190911, 20190921, 20191001, 20191011, 20191021,
#        20191101, 20191111, 20191121, 20191201, 20191211, 20191221,
#        20200101, 20200111, 20200121, 20200201, 20200211, 20200221,
#        20200301, 20200311, 20200321, 20200401, 20200411, 20200421,
#        20200501, 20200511, 20200521, 20200601, 20200611, 20200621,
#        20200701, 20200711, 20200721, 20200801, 20200811, 20200821,
#        20200901, 20200911, 20200921, 20201001, 20201011, 20201021,
#        20201101, 20201111, 20201121, 20201201, 20201211, 20201221,
#        20210101, 20210111, 20210121, 20210201, 20210211, 20210221,
#        20210301, 20210311, 20210321, 20210401, 20210411, 20210421,
#        20210501, 20210511, 20210521, 20210601, 20210611, 20210621,
#        20210701, 20210711, 20210721, 20210801, 20210811, 20210821,
#        20210901, 20210911, 20210921, 20211001, 20211011, 20211021,
#        20211101, 20211111, 20211121, 20211201, 20211211, 20211221,
#        20220101, 20220111, 20220121, 20220201, 20220211, 20220221,
#        20220301, 20220311, 20220321, 20220401, 20220411, 20220421,
#        20220501, 20220511, 20220521, 20220601, 20220611, 20220621,
#        20220701, 20220711, 20220721, 20220801, 20220811, 20220821,
#        20220901, 20220911, 20220921, 20221001, 20221011, 20221021,
#        20221101, 20221111, 20221121, 20221201, 20221211, 20221221,
#        20230101, 20230111, 20230121, 20230201, 20230211, 20230221,
#        20230301, 20230311, 20230321, 20230401, 20230411, 20230421,
#        20230501, 20230511, 20230521, 20230601, 20230611, 20230621,
#        20230701, 20230711, 20230721, 20230801, 20230811, 20230821,
#        20230901, 20230911, 20230921, 20231001, 20231011, 20231021,
#        20231101, 20231111, 20231121, 20231201, 20231211, 20231221,
#        20240101, 20240111, 20240121, 20240201, 20240211, 20240221,
#        20240301, 20240311, 20240321, 20240401, 20240411, 20240421,
#        20240501, 20240511, 20240521, 20240601, 20240611, 20240621,
#        20240701, 20240711, 20240721, 20240801, 20240811, 20240821,
#        20240901, 20240911, 20240921, 20241001, 20241011, 20241021,
#        20241101, 20241111, 20241121, 20241201, 20241211, 20241221,
#        20250101, 20250111, 20250121, 20250201, 20250211, 20250221,
#        20250301, 20250311, 20250321, 20250401, 20250411, 20250421,
#        20250501, 20250511, 20250521, 20250601, 20250611, 20250621,
#        20250701, 20250711, 20250721, 20250801, 20250811, 20250821,
#        20250901, 20250911, 20250921, 20251001, 20251011, 20251021,
#        20251101, 20251111, 20251121, 20251201, 20251211, 20251221],
#       dtype=int32)

# %%
store = zarr.storage.LocalStore(zarr_path)
compressor = zarr.codecs.BloscCodec()

root = zarr.group(store=store, zarr_format=3)
dataset = "ST"
ds = root.require_group(dataset)

res = 10

x0 = 4200005
y0 = 2500005

x_extent = np.arange(x0, 4900005, res)
y_extent = np.arange(y0, 3000005, res)

# %%
print(ds.path)
# Out:
# ST

# %%
time_array = ds.require_array(
    name="time",
    shape=(len(dates_int),),
    dtype="int32",
    chunks=(len(dates_int),),
    dimension_names=("time",),
    attributes={
        "units": "YYYYMMDD",
        "calendar": "noleap",
    },
)
time_array[:] = dates_int

x_array = ds.require_array(
    name="x",
    shape=x_extent.shape,
    dtype="int32",
    chunks=(len(x_extent),),
    dimension_names=("x",),
)
x_array[:] = x_extent

y_array = ds.require_array(
    name="y",
    shape=y_extent.shape,
    dtype="int32",
    chunks=(len(y_extent),),
    dimension_names=("y",),
)
y_array[:] = y_extent


# zarr.consolidate_metadata(store)

# %%
time_array
# Out:
# <Array file://../../../eodc/products/eodc/clms_vegetation_total_productivity/CLMS.zarr/ST/time shape=(324,) dtype=int32>

# %%
productType = "PPI"

# %%
test = rioxarray.open_rasterio("../../../eodc/private/tempearth/CLMS/ST_QFLAG_NEW/ST_20221221T000000_S2_E47N29-03035-010m_V105_QFLAG.tif")

print(test)
# Out:
# <xarray.DataArray (band: 1, y: 10000, x: 10000)> Size: 200MB
# [100000000 values with dtype=int16]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 80kB 4.7e+06 4.7e+06 4.7e+06 ... 4.8e+06 4.8e+06
#   * y            (y) float64 80kB 3e+06 3e+06 3e+06 ... 2.9e+06 2.9e+06 2.9e+06
#     spatial_ref  int64 8B 0
# Attributes:
#     TIFFTAG_DATETIME:   2022:12:21 00:00:00
#     TIFFTAG_COPYRIGHT:  Copernicus service information 2023
#     file_creation:      2023:05:10 09:22:12
#     Flag_meaning:       (no data (time series was not processed), Filled (ext...
#     Flag_value:         (0, 1, 2, 3, 4, 5)
#     input_time_window:  2018-10-01 to 2022-02-29
#     TIIFTAG_SOFTWARE:   Timesat : TIMESAT4.1.8
#     AREA_OR_POINT:      Area
#     _FillValue:         0
#     scale_factor:       1.0
#     add_offset:         0.0
#     long_name:          Seasonal Trajectory Quality Flag

# %%
fill_value_PPI = -32768
scale_factor_PPI =  0.0001

attributes_PPI={
        "TIFFTAG_COPYRIGHT": "Copernicus service information 2023",
        "scale_factor": scale_factor_PPI,
        "_FillValue": fill_value_PPI,
        "TIIFTAG_SOFTWARE": "Timesat : TIMESAT4.1.8",
        "PhysRange": "0 to 3",
        "add_offset": 0.0,
        "long_name": "Plant Phenology Index obtained via timesat fitting",
    }


fill_value_QFLAG = 0
scale_factor_QFLAG =  1.0

attributes_QFLAG={
        "TIFFTAG_COPYRIGHT": "Copernicus service information 2023",
        "scale_factor": scale_factor_QFLAG,
        "_FillValue": fill_value_QFLAG,
        "TIIFTAG_SOFTWARE": "Timesat : TIMESAT4.1.8",
        "Flag_value": (0, 1, 2, 3, 4, 5),
        "add_offset": 0.0,
        "long_name": "Seasonal Trajectory Quality Flag",
    }

# %%
shape = (len(dates_int), len(y_extent), len(x_extent))
chunk_shape = (1, 10000, 10000)

fv =  globals()[f"fill_value_{productType}"]

if -32768 <= fv < 0:
    dtype = "int16"
elif 0 <= fv <= 65535:
    dtype = "uint16"

# %%
data_array = ds.require_array(
    name=productType,
    shape=shape,
    chunks=chunk_shape,
    dtype=dtype,
    fill_value = globals()[f"fill_value_{productType}"],
    compressor=compressor,
    dimension_names=["time", "y", "x"],
    attributes=globals()[f"attributes_{productType}"],
    overwrite=False
)
# Out:
# /home/koenifra/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:1119: UserWarning: The `compressor` argument is deprecated. Use `compressors` instead.
#   compressors = _parse_deprecated_compressor(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:747, in AsyncGroup._getitem_consolidated(self, store_path, key, prefix)
#     746 try:
# --> 747     metadata = metadata.consolidated_metadata.metadata[indexer]
#     748 except KeyError as e:
#     749     # The Group Metadata has consolidated metadata, but the key
#     750     # isn't present. We trust this to mean that the key isn't in
#     751     # the hierarchy, and *don't* fall back to checking the store.
#
# KeyError: 'PPI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:1245, in AsyncGroup.require_array(self, name, shape, dtype, exact, **kwargs)
#    1244 try:
# -> 1245     ds = await self.getitem(name)
#    1246     if not isinstance(ds, AsyncArray):
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:709, in AsyncGroup.getitem(self, key)
#     708 if self.metadata.consolidated_metadata is not None:
# --> 709     return self._getitem_consolidated(store_path, key, prefix=self.name)
#     710 try:
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:753, in AsyncGroup._getitem_consolidated(self, store_path, key, prefix)
#     752         msg = f"'{key}' not found in consolidated metadata."
# --> 753         raise KeyError(msg) from e
#     755 # update store_path to ensure that AsyncArray/Group.name is correct
#
# KeyError: "'PPI' not found in consolidated metadata."
#
# During handling of the above exception, another exception occurred:
#
# ContainsArrayError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data_array = ds.require_array(
#       2     name=productType,
#       3     shape=shape,
#       4     chunks=chunk_shape,
#       5     dtype=dtype,
#       6     fill_value = globals()[f"fill_value_{productType}"],
#       7     compressor=compressor,
#       8     dimension_names=["time", "y", "x"],
#       9     attributes=globals()[f"attributes_{productType}"],
#      10     overwrite=False
#      11 )
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:2621, in Group.require_array(self, name, shape, **kwargs)
#    2605 def require_array(self, name: str, *, shape: ShapeLike, **kwargs: Any) -> Array:
#    2606     """Obtain an array, creating if it doesn't exist.
#    2607
#    2608     Other `kwargs` are as per :func:`zarr.Group.create_array`.
#    (...)   2619     a : Array
#    2620     """
# -> 2621     return Array(self._sync(self._async_group.require_array(name, shape=shape, **kwargs)))
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/sync.py:208, in SyncMixin._sync(self, coroutine)
#     205 def _sync(self, coroutine: Coroutine[Any, Any, T]) -> T:
#     206     # TODO: refactor this to to take *args and **kwargs and pass those to the method
#     207     # this should allow us to better type the sync wrapper
# --> 208     return sync(
#     209         coroutine,
#     210         timeout=config.get("async.timeout"),
#     211     )
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/sync.py:163, in sync(coro, loop, timeout)
#     160 return_result = next(iter(finished)).result()
#     162 if isinstance(return_result, BaseException):
# --> 163     raise return_result
#     164 else:
#     165     return return_result
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/sync.py:119, in _runner(coro)
#     114 """
#     115 Await a coroutine and return the result of running it. If awaiting the coroutine raises an
#     116 exception, the exception will be returned.
#     117 """
#     118 try:
# --> 119     return await coro
#     120 except Exception as ex:
#     121     return ex
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:1261, in AsyncGroup.require_array(self, name, shape, dtype, exact, **kwargs)
#    1259             raise TypeError(f"Incompatible dtype ({ds.dtype} vs {dtype})")
#    1260 except KeyError:
# -> 1261     ds = await self.create_array(name, shape=shape, dtype=dtype, **kwargs)
#    1263 return ds
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/group.py:1122, in AsyncGroup.create_array(self, name, shape, dtype, chunks, shards, filters, compressors, compressor, serializer, fill_value, order, attributes, chunk_key_encoding, dimension_names, storage_options, overwrite, config)
#    1027 """Create an array within this group.
#    1028
#    1029 This method lightly wraps :func:`zarr.core.array.create_array`.
#    (...)   1117
#    1118 """
#    1119 compressors = _parse_deprecated_compressor(
#    1120     compressor, compressors, zarr_format=self.metadata.zarr_format
#    1121 )
# -> 1122 return await create_array(
#    1123     store=self.store_path,
#    1124     name=name,
#    1125     shape=shape,
#    1126     dtype=dtype,
#    1127     chunks=chunks,
#    1128     shards=shards,
#    1129     filters=filters,
#    1130     compressors=compressors,
#    1131     serializer=serializer,
#    1132     fill_value=fill_value,
#    1133     order=order,
#    1134     zarr_format=self.metadata.zarr_format,
#    1135     attributes=attributes,
#    1136     chunk_key_encoding=chunk_key_encoding,
#    1137     dimension_names=dimension_names,
#    1138     storage_options=storage_options,
#    1139     overwrite=overwrite,
#    1140     config=config,
#    1141 )
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/array.py:4456, in create_array(store, name, shape, dtype, data, chunks, shards, filters, compressors, serializer, fill_value, order, zarr_format, attributes, chunk_key_encoding, dimension_names, storage_options, overwrite, config, write_data)
#    4451 mode: Literal["a"] = "a"
#    4453 store_path = await make_store_path(
#    4454     store, path=name, mode=mode, storage_options=storage_options
#    4455 )
# -> 4456 return await init_array(
#    4457     store_path=store_path,
#    4458     shape=shape_parsed,
#    4459     dtype=dtype_parsed,
#    4460     chunks=chunks,
#    4461     shards=shards,
#    4462     filters=filters,
#    4463     compressors=compressors,
#    4464     serializer=serializer,
#    4465     fill_value=fill_value,
#    4466     order=order,
#    4467     zarr_format=zarr_format,
#    4468     attributes=attributes,
#    4469     chunk_key_encoding=chunk_key_encoding,
#    4470     dimension_names=dimension_names,
#    4471     overwrite=overwrite,
#    4472     config=config,
#    4473 )
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/core/array.py:4201, in init_array(store_path, shape, dtype, chunks, shards, filters, compressors, serializer, fill_value, order, zarr_format, attributes, chunk_key_encoding, dimension_names, overwrite, config)
#    4199         await ensure_no_existing_node(store_path, zarr_format=zarr_format)
#    4200 else:
# -> 4201     await ensure_no_existing_node(store_path, zarr_format=zarr_format)
#    4203 shard_shape_parsed, chunk_shape_parsed = _auto_partition(
#    4204     array_shape=shape_parsed, shard_shape=shards, chunk_shape=chunks, dtype=dtype_parsed
#    4205 )
#    4206 chunks_out: tuple[int, ...]
#
# File ~/envs/zarr3/lib/python3.11/site-packages/zarr/storage/_common.py:414, in ensure_no_existing_node(store_path, zarr_format)
#     411     extant_node = await _contains_node_v3(store_path)
#     413 if extant_node == "array":
# --> 414     raise ContainsArrayError(store_path.store, store_path.path)
#     415 elif extant_node == "group":
#     416     raise ContainsGroupError(store_path.store, store_path.path)
#
# ContainsArrayError: An array exists in store LocalStore('file://../../../eodc/products/eodc/clms_vegetation_total_productivity/CLMS.zarr') at path 'ST/PPI'.

# %%
root = zarr.open_group(
    store=store,
    mode="a",
    zarr_format=3,
    use_consolidated=False,   # critical
)

data_array = root["ST"]["PPI"]

# %%
date_to_index = {int(d): i for i, d in enumerate(dates_int)}

x0 = x_extent[0]  # 4_200_000
y0 = y_extent[0]  # 2_500_000
res = 10          # 10 m pro Pixel

path = f"../../../eodc/private/tempearth/CLMS/ST_{productType}/*.tif"


# for y in dates_int[180:191]:
for y in dates_int[213:]:
    print(f"date = {y}")
    print(f"index = {date_to_index[y]}")

    tif_files = sorted([
        f for f in glob.glob(path)
        if "100m" not in f and str(y) in os.path.basename(f)
    ])
        
    for filepath in tif_files:

        print(f"file: {filepath}")

        try:
            file = rioxarray.open_rasterio(filepath)
            tp = file.values.astype("float32")
        except Exception as e:
            print(f"Unexpected error with file: {filepath}")
            print(f"Error: {e}")
            continue


        # Extract both xmin and ymin
        match = re.search(r'E(\d+)N(\d+)', filepath)
        if match:
            # 1) Kachelecken (untere linke Ecke) in Meter
            xmin_corner = int(match.group(1)) * 100000  # z.B. 42 → 4_200_000
            ymin_corner = int(match.group(2)) * 100000

            # 2) Erste Zellmitte in dieser Kachel (wie im TIF)
            xmin_center = xmin_corner + res / 2       # 4_200_000 + 5 = 4_200_005
            ymin_center = ymin_corner + res / 2
        else:
            print("No match found.")
            continue

        ny_tile = tp.shape[1]   # Pixel in y
        nx_tile = tp.shape[2]   # Pixel in x

        xmax_center = xmin_center + (nx_tile - 1) * res
        ymax_center = ymin_center + (ny_tile - 1) * res

        # print(f"tile centers x: {xmin_center} .. {xmax_center}")
        # print(f"tile centers y: {ymin_center} .. {ymax_center}")

        ix_min = int((xmin_center - x0) // res)
        ix_max = ix_min + nx_tile        # slice-Ende ist exklusiv
        iy_min = int((ymin_center - y0) // res)
        iy_max = iy_min + ny_tile

        start_idx = date_to_index[y]
        end_idx   = start_idx + tp.shape[0]

        # print(start_idx)
        
        tp = tp[:, ::-1, :]
        data_array[start_idx:end_idx, iy_min:iy_max, ix_min:ix_max] = tp

        # Free memory
        del tp
        gc.collect()
# Out:
# date = 20221201
# index = 213
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E42N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E42N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E42N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E42N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E43N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E43N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E43N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E43N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E44N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E44N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E44N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E44N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E45N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E45N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E45N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E45N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E46N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E46N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E46N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E46N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E47N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E47N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E47N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E47N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E47N29-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E48N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E48N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E48N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221201T000000_S2_E48N29-03035-010m_V105_PPI.tif
# date = 20221211
# index = 214
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E42N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E42N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E42N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E42N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E43N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E43N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E43N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E43N28-03035-010m_V105_PPI.tif
# Unexpected error with file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E43N28-03035-010m_V105_PPI.tif
# Error: Read failed. See previous exception for details.
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E44N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E44N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E44N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E44N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E45N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E45N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E45N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E45N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E46N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E46N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E46N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E46N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E47N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E47N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E47N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E47N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E47N29-03035-010m_V105_PPI.tif
# Unexpected error with file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E47N29-03035-010m_V105_PPI.tif
# Error: Read failed. See previous exception for details.
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E48N26-03035-010m_V105_PPI.tif
# Unexpected error with file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E48N26-03035-010m_V105_PPI.tif
# Error: Read failed. See previous exception for details.
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E48N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E48N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E48N29-03035-010m_V105_PPI.tif
# Unexpected error with file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221211T000000_S2_E48N29-03035-010m_V105_PPI.tif
# Error: Read failed. See previous exception for details.
# date = 20221221
# index = 215
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E42N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E42N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E42N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E42N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E43N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E43N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E43N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E43N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E44N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E44N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E44N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E44N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E45N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E45N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E45N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E45N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E46N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E46N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E46N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E46N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E47N25-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E47N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E47N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E47N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E47N29-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E48N26-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E48N27-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E48N28-03035-010m_V105_PPI.tif
# file: ../../../eodc/private/tempearth/CLMS/ST_PPI/ST_20221221T000000_S2_E48N29-03035-010m_V105_PPI.tif
# date = 20230101
# index = 216
# date = 20230111
# index = 217
# date = 20230121
# index = 218
# date = 20230201
# index = 219
# date = 20230211
# index = 220
# date = 20230221
# index = 221
# date = 20230301
# index = 222
# date = 20230311
# index = 223
# date = 20230321
# index = 224
# date = 20230401
# index = 225
# date = 20230411
# index = 226
# date = 20230421
# index = 227
# date = 20230501
# index = 228
# date = 20230511
# index = 229
# date = 20230521
# index = 230
# date = 20230601
# index = 231
# date = 20230611
# index = 232
# date = 20230621
# index = 233
# date = 20230701
# index = 234
# date = 20230711
# index = 235
# date = 20230721
# index = 236
# date = 20230801
# index = 237
# date = 20230811
# index = 238
# date = 20230821
# index = 239
# date = 20230901
# index = 240
# date = 20230911
# index = 241
# date = 20230921
# index = 242
# date = 20231001
# index = 243
# date = 20231011
# index = 244
# date = 20231021
# index = 245
# date = 20231101
# index = 246
# date = 20231111
# index = 247
# date = 20231121
# index = 248
# date = 20231201
# index = 249
# date = 20231211
# index = 250
# date = 20231221
# index = 251
# date = 20240101
# index = 252
# date = 20240111
# index = 253
# date = 20240121
# index = 254
# date = 20240201
# index = 255
# date = 20240211
# index = 256
# date = 20240221
# index = 257
# date = 20240301
# index = 258
# date = 20240311
# index = 259
# date = 20240321
# index = 260
# date = 20240401
# index = 261
# date = 20240411
# index = 262
# date = 20240421
# index = 263
# date = 20240501
# index = 264
# date = 20240511
# index = 265
# date = 20240521
# index = 266
# date = 20240601
# index = 267
# date = 20240611
# index = 268
# date = 20240621
# index = 269
# date = 20240701
# index = 270
# date = 20240711
# index = 271
# date = 20240721
# index = 272
# date = 20240801
# index = 273
# date = 20240811
# index = 274
# date = 20240821
# index = 275
# date = 20240901
# index = 276
# date = 20240911
# index = 277
# date = 20240921
# index = 278
# date = 20241001
# index = 279
# date = 20241011
# index = 280
# date = 20241021
# index = 281
# date = 20241101
# index = 282
# date = 20241111
# index = 283
# date = 20241121
# index = 284
# date = 20241201
# index = 285
# date = 20241211
# index = 286
# date = 20241221
# index = 287
# date = 20250101
# index = 288
# date = 20250111
# index = 289
# date = 20250121
# index = 290
# date = 20250201
# index = 291
# date = 20250211
# index = 292
# date = 20250221
# index = 293
# date = 20250301
# index = 294
# date = 20250311
# index = 295
# date = 20250321
# index = 296
# date = 20250401
# index = 297
# date = 20250411
# index = 298
# date = 20250421
# index = 299
# date = 20250501
# index = 300
# date = 20250511
# index = 301
# date = 20250521
# index = 302
# date = 20250601
# index = 303
# date = 20250611
# index = 304
# date = 20250621
# index = 305
# date = 20250701
# index = 306
# date = 20250711
# index = 307
# date = 20250721
# index = 308
# date = 20250801
# index = 309
# date = 20250811
# index = 310
# date = 20250821
# index = 311
# date = 20250901
# index = 312
# date = 20250911
# index = 313
# date = 20250921
# index = 314
# date = 20251001
# index = 315
# date = 20251011
# index = 316
# date = 20251021
# index = 317
# date = 20251101
# index = 318
# date = 20251111
# index = 319
# date = 20251121
# index = 320
# date = 20251201
# index = 321
# date = 20251211
# index = 322
# date = 20251221
# index = 323
